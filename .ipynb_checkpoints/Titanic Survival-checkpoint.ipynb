# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd 
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("train.csv")

# %%
df.shape
# Out:
# (891, 12)

# %%
pd.max_cols = 12

# %%
pd.set_option('display.max_columns', None)

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop('Cabin',axis=1,inplace=True)
df.drop('Name',axis=1,inplace=True)

# %%
for col in df.columns:
    print(col,len(df[col].unique()))
# Out:
# PassengerId 891
# Survived 2
# Pclass 3
# Sex 2
# Age 89
# SibSp 7
# Parch 7
# Ticket 681
# Fare 248
# Embarked 4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include="O")
# Out:
#          Sex    Ticket Embarked
# count    891       891      889
# unique     2       681        3
# top     male  CA. 2343        S
# freq     577         7      644

# %%
num_cols = df._get_numeric_data().columns
obj_cols = df.select_dtypes('object').columns

# %%
num_cols
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
obj_cols
# Out:
# Index(['Sex', 'Ticket', 'Embarked'], dtype='object')

# %%
df[df['Survived']==True].groupby(['Sex']).count()['Survived'].plot(kind='bar')

# %%
sns.catplot(x="Sex", y="Survived", hue="Pclass", kind="bar", data=df)

# %%
sns.catplot(x="Embarked", y="Survived", hue="Pclass", kind="bar", data=df)

# %%
sns.catplot(x="SibSp", y="Survived", hue="Pclass", kind="bar", data=df)

# %%
sns.pairplot(df)

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,10)) 
sns.set(font_scale=1.5) 
sns.heatmap(df.dropna().corr(), annot=True,ax=ax)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Embarked'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ### mode() returns an array
# - get mode()[0] first element of mode

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
df['Age'].plot.hist(bins=12, alpha=1)

# %%
df['Fare'].plot.hist(bins=12, alpha=1)

# %%
df['SibSp'].plot.hist(bins=12, alpha=1)

# %%
df['Parch'].plot.hist(bins=12, alpha=1)

# %%
from IPython.display import Image
Image("distribution.png")

# %%
print(df.Age.mean())
print(df.Age.median())
print(df.Age.mode()[0])
# Out:
# 29.699117647058763
# 29.69911764705882
# 29.69911764705882

# %%
print(df.Fare.mean())
print(df.Fare.median())
print(df.Fare.mode()[0])
# Out:
# 32.2042079685746
# 14.4542
# 8.05

# %%
df['zscore_age']=((df.Age-df.Age.mean())/df.Age.std())
df.drop(df[(df.zscore_age>3)|(df.zscore_age<-3)].index,axis=0,inplace=True)

# %%
def binary_encoder(data):
    if data == 'female':
        return 0
    else :
        return 1

# %%
df['Sex']=df['Sex'].apply(binary_encoder)

# %%
df['Sex']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 884, dtype: int64

# %%
from sklearn import preprocessing
encoder = preprocessing.LabelEncoder()
df['Ticket'] = encoder.fit_transform(df['Ticket'])

# %%
df['Ticket']
# Out:
# 0      520
# 1      592
# 2      663
# 3       49
# 4      469
#       ...
# 886    101
# 887     14
# 888    669
# 889      8
# 890    463
# Name: Ticket, Length: 884, dtype: int32

# %%
df[df['Survived']==True]['Ticket'].plot.hist(bins=12, alpha=1)

# %%
df[df['Survived']==False]['Ticket'].plot.hist(bins=12, alpha=1)

# %%
pass_id = df['PassengerId']
X = df[['Age','Fare','Sex','Ticket','Embarked','SibSp','Parch']]
y = df['Survived']

# %%
X
# Out:
#            Age     Fare  Sex  Ticket Embarked  SibSp  Parch
# 0    22.000000   7.2500    1     520        S      1      0
# 1    38.000000  71.2833    0     592        C      1      0
# 2    26.000000   7.9250    0     663        S      0      0
# 3    35.000000  53.1000    0      49        S      1      0
# 4    35.000000   8.0500    1     469        S      0      0
# ..         ...      ...  ...     ...      ...    ...    ...
# 886  27.000000  13.0000    1     101        S      0      0
# 887  19.000000  30.0000    0      14        S      0      0
# 888  29.699118  23.4500    0     669        S      1      2
# 889  26.000000  30.0000    1       8        C      0      0
# 890  32.000000   7.7500    1     463        Q      0      0
#
# [884 rows x 7 columns]

# %%
dummies = pd.get_dummies(df['Embarked'])

# %%
dummies
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [884 rows x 3 columns]

# %%
X.drop('Embarked',axis=1,inplace=True)

# %%
cols = dummies.columns

# %%
X[cols]=dummies

# %%
X
# Out:
#            Age     Fare  Sex  Ticket  SibSp  Parch  C  Q  S
# 0    22.000000   7.2500    1     520      1      0  0  0  1
# 1    38.000000  71.2833    0     592      1      0  1  0  0
# 2    26.000000   7.9250    0     663      0      0  0  0  1
# 3    35.000000  53.1000    0      49      1      0  0  0  1
# 4    35.000000   8.0500    1     469      0      0  0  0  1
# ..         ...      ...  ...     ...    ...    ... .. .. ..
# 886  27.000000  13.0000    1     101      0      0  0  0  1
# 887  19.000000  30.0000    0      14      0      0  0  0  1
# 888  29.699118  23.4500    0     669      1      2  0  0  1
# 889  26.000000  30.0000    1       8      0      0  1  0  0
# 890  32.000000   7.7500    1     463      0      0  0  1  0
#
# [884 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2048)

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train.shape[0] == y_train.shape[0]
# Out:
# True

# %%
def apply_model(clf,X_train,X_test,y_train,y_test):
    clf.fit(X_train,y_train)
    predictions = clf.predict(X_test)   
    print('Unscaled data result')
    print(accuracy_score(y_test,predictions))
    scaler = StandardScaler()
    X_train[cols] = scaler.fit(X_train[cols].values).transform(X_train[cols].values)
    X_test[cols]  =  scaler.fit(X_test[cols].values).transform(X_test[cols].values)
    clf.fit(X_train,y_train)
    predictions = clf.predict(X_test)   
    print('Scaled data result')
    print(accuracy_score(y_test,predictions))

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(max_iter=200)
apply_model(clf,X_train,X_test,y_train,y_test)
# Out:
# Unscaled data result
# 0.8248587570621468
# Scaled data result
# 0.8192090395480226

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb_clf = GradientBoostingClassifier(random_state=1024,n_estimators=150)
apply_model(gb_clf,X_train,X_test,y_train,y_test)
# Out:
# Unscaled data result
# 0.8531073446327684
# Scaled data result
# 0.8531073446327684

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_clf = AdaBoostClassifier(n_estimators=100, random_state=0)
apply_model(ada_clf,X_train,X_test,y_train,y_test)
# Out:
# Unscaled data result
# 0.8305084745762712
# Scaled data result
# 0.8305084745762712

# %%
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
bag_clf = BaggingClassifier(base_estimator=SVC(),n_estimators=20, random_state=0)
apply_model(bag_clf,X_train,X_test,y_train,y_test)
# Out:
# Unscaled data result
# 0.7175141242937854
# Scaled data result
# 0.7175141242937854

# %%
from sklearn.tree import DecisionTreeClassifier
tree_clf = DecisionTreeClassifier()
apply_model(tree_clf,X_train,X_test,y_train,y_test)
# Out:
# Unscaled data result
# 0.7966101694915254
# Scaled data result
# 0.807909604519774

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(n_estimators=100)

apply_model(rf_clf,X_train,X_test,y_train,y_test)
# Out:
# Unscaled data result
# 0.8531073446327684
# Scaled data result
# 0.8361581920903954

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier(n_neighbors=30)
apply_model(knn_clf,X_train,X_test,y_train,y_test)
# Out:
# Unscaled data result
# 0.7344632768361582
# Scaled data result
# 0.7344632768361582

# %%
from sklearn.ensemble import VotingClassifier
e_clf = VotingClassifier(estimators=[('logis', clf), ('gb_clfgb_clf', gb_clf), ('rf_clf', rf_clf),('ada_clf',ada_clf),('knn_clf',knn_clf)], voting='hard')
apply_model(e_clf,X_train,X_test,y_train,y_test)
# Out:
# Unscaled data result
# 0.8700564971751412
# Scaled data result
# 0.8700564971751412

# %%
test = pd.read_csv("test.csv")

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
pass_id = test['PassengerId']
X_test = test[['Age','Fare','Sex','Ticket','Embarked','SibSp','Parch']]
X_test['Ticket'] =encoder.fit_transform(X_test['Ticket'])

# %%
X_test.Fare.fillna(X.Fare.mean(),inplace=True)

# %%
X_test.Age.fillna(X.Age.mean(),inplace=True)

# %%
X_test.isnull().sum()
# Out:
# Age         0
# Fare        0
# Sex         0
# Ticket      0
# Embarked    0
# SibSp       0
# Parch       0
# dtype: int64

# %%
X_test['Sex'] = X_test['Sex'].apply(binary_encoder)
X_test.head()
# Out:
#     Age     Fare  Sex  Ticket Embarked  SibSp  Parch
# 0  34.5   7.8292    1     152        Q      0      0
# 1  47.0   7.0000    0     221        S      1      0
# 2  62.0   9.6875    1      73        Q      0      0
# 3  27.0   8.6625    1     147        S      0      0
# 4  22.0  12.2875    0     138        S      1      1

# %%
dummies = pd.get_dummies(df['Embarked'])
X_test.drop('Embarked',axis=1,inplace=True)
X_test[dummies.columns]=dummies

# %%
X_test.fillna(0,inplace=True)

# %%
X_test
# Out:
#            Age      Fare  Sex  Ticket  SibSp  Parch    C    Q    S
# 0    34.500000    7.8292    1     152      0      0  0.0  0.0  1.0
# 1    47.000000    7.0000    0     221      1      0  1.0  0.0  0.0
# 2    62.000000    9.6875    1      73      0      0  0.0  0.0  1.0
# 3    27.000000    8.6625    1     147      0      0  0.0  0.0  1.0
# 4    22.000000   12.2875    0     138      1      1  0.0  0.0  1.0
# ..         ...       ...  ...     ...    ...    ...  ...  ...  ...
# 413  29.361328    8.0500    1     267      0      0  0.0  0.0  1.0
# 414  39.000000  108.9000    0     324      0      0  0.0  0.0  1.0
# 415  38.500000    7.2500    1     346      0      0  0.0  0.0  1.0
# 416  29.361328    8.0500    1     220      0      0  0.0  0.0  1.0
# 417  29.361328   22.3583    1     105      1      1  0.0  0.0  1.0
#
# [418 rows x 9 columns]

# %%
prediction = e_clf.predict(X_test)

# %%
len(prediction)==len(pass_id)
# Out:
# True

# %%
results = pd.DataFrame()
results['PassengerId']=pass_id.values
results['Survived']=prediction
results.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
results.to_csv('results.csv',index=None)
